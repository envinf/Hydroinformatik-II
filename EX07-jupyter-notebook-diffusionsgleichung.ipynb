# %%
<!--- Kommentar: HTML code --->
<hr> <!--- horizontale Linie --->
<img src="tu-dresden-blue.png" alt="drawing" width="200"/> <!--- Abbildung --->
<hr>

# %%
<!--- Text --->
Professur für Angewandte Umweltsystemanalyse an der TU Dresden <br/>
Prof. Dr.-Ing. habil. Olaf Kolditz <br/>
***Hydroinformatik II (HyBHW-2-01)*** <br/>
[Lehre-Webseite](https://www.ufz.de/index.php?de=40425)
<hr>

**Exercise 2 - Analytical solution for diffusion equation** <br/>
<hr>

# %%
<!--- Formeln --->
**Problemstellung**
* Partial Differential Equation:
$\frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$
* Initial condition:
$u(t=0,x)=1$
* Boundary conditions
$u(t,x=0)=0$
$u(t,x=1)=0$

**Analytische Lösung**
<hr>

# %%
#Kommentar
#Python code
##Module laden
import math
import matplotlib.pylab as plt
##Daten und Variablen anlegen
PI = 3.1415926
numPoints = 10
alpha = 1.0
t = [0.1,0.5,1.0,2.0]
x = []
y = []
##Berechnung
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(PI*x[i]) * math.exp(-alpha*n*n))
    plt.plot(x,y,color='red',marker="o")
    x = []
    y = []
##Plotten
plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.show()
